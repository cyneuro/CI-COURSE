# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cyneuro/CI-COURSE/blob/main/Colab_1_Building_Your_First_Workflow.ipynb)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# # 🧭 Colab 1: Building Your First Research Workflow
#
#
#
#
#
#
#
# ## Single-Subject EEG Emotion Analysis Pipeline
#
#
#
#
#
#
#
# ### Scientific Workflows for Brain and Behavioral Research
#
#
#
#
#
#
#
# ### National Science Foundation Supported Learning Initiative (Award No. OAC-2417875)
#
#
#
#
#
#
#
# #### Semester Course — Colab 1 of 5 (Weeks 1–2)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ## Overview
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# This Colab now runs on the Workshop's actual current curriculum: real EEG data recorded while a participant played four emotionally different computer games (boring, calm, horror, funny). You'll build a four-stage pipeline — data acquisition, per-electrode statistical analysis, visualization, and documentation — for a single participant (S01), acting as a **Workflow Designer** the whole way: you pass each "AI Prompt Challenge" to an AI coding assistant, evaluate what it returns, and drop it into the notebook.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# This Colab is split into two submissions:
#
#
#
#
#
#
#
# - **Colab 1-1** (end of Week 1): data acquisition and statistical analysis.
#
#
#
#
#
#
#
# - **Colab 1-2** (end of Week 2, combined): visualization, documentation, and the Embedded Playground tasks.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
#
#
#
#
#
# ## 📋 Set Up Your Profile

# %%
# PROFILE SETUP







student_name = "Your Name"







institution = "Your University/Organization"







team_name = "Your Team Name"







print(f"✅ Notebook initialized for {student_name} ({institution}) — Team {team_name}")

# %% [markdown]
# ***
#
# ## 🪜 Your Cumulative Microcredential Ladder
#
#
#
# Starting here in Colab 1, you'll build a **single, growing personal document** that follows you through all five Colabs — not five separate, disconnected knowledge sections. Each Colab adds new rungs to five ladders that run the whole semester:
#
#
#
# 1. **CI-Hardware** — micro:bit → laptop → local server → institutional cluster → FABRIC → ACCESS → NAIRR → (horizon: neuromorphic computing)
#
# 2. **CI-Software** — machine code → assembly → compiled languages → Python-era scripting → frameworks → vibe coding → (horizon: fully agentic coding)
#
# 3. **Compute Access Model** — manual sessions → batch/Slurm → persistent testbed sessions → (horizon: serverless/on-demand)
#
# 4. **AI/Agentic** — classical ML → generative AI → AI-assisted coding → agentic AI → projected trajectory
#
# 5. **Team/Process** — Forming → Storming → Norming → Performing → Adjourning, and the brain circuits underneath them
#
#
#
# **The rule for every rung you add: it must carry a real number.** Not "national resources are bigger than a laptop" — how many cores, how much memory, how much does an hour actually cost, how fast is the market actually growing. A rung without a number isn't finished.
#
#
#
# **Mechanics:** In Colab 1, start your ladder document in the cell below. In every Colab after this one, copy your ladder forward from the previous Colab, then add that Colab's new rung(s) beneath what's already there. By Colab 5, you'll have one continuous, self-authored record of everything this course covered — in your own words, with your own researched numbers.

# %%
# 🪜 YOUR CUMULATIVE MICROCREDENTIAL LADDER — start here, carry this forward into every Colab

"""

=== CI-HARDWARE LADDER ===

[Add Colab 1's rung(s) below]



=== CI-SOFTWARE LADDER ===

[Add Colab 1's rung(s) below]



=== COMPUTE ACCESS MODEL LADDER ===

(introduced in Colab 3)



=== AI/AGENTIC LADDER ===

(introduced in Colab 2/4)



=== TEAM/PROCESS LADDER ===

(introduced in Colab 5)

"""

# %% [markdown]
# ### 🧭 Activity A.0 — The CI-Hardware Tier Ladder: From Laptop to National Resource
#
#
#
# Before comparing *how* you access compute (Activity A.1, next), it's worth knowing the actual scale differences between tiers of hardware — with real numbers, not just "bigger."
#
#
#
# | Tier | Typical scale | Who it serves |
#
# |---|---|---|
#
# | **micro:bit** | 128 KB of RAM total | One device, one task (you'll work with this directly in Colab 3) |
#
# | **Laptop** | ~8–16 CPU cores, 16–32 GB RAM | One person |
#
# | **Local/departmental server** | ~32–128 cores, 256 GB–1 TB RAM, often 1–8 GPUs | One lab or department, shared |
#
# | **Institutional HPC cluster ("local mainframe")** | Hundreds to thousands of cores across many networked machines, dozens to hundreds of GPUs | An entire university, shared and scheduled |
#
# | **National resource (FABRIC)** | A testbed distributed across dozens of sites nationwide, built for large-scale, reconfigurable experimentation | Researchers nationwide, by project allocation |
#
# | **The broader ecosystem (ACCESS, formerly XSEDE)** | Coordinates allocations across *multiple* national supercomputing centers at once, collectively offering computing power measured in petaflops (quadrillions of operations per second) | All NSF-supported research nationally |
#
# | **NAIRR (National AI Research Resource)** | A newer, AI-specific national resource, launched specifically to give researchers access to the GPU-heavy infrastructure large AI models require | AI/ML researchers nationally |
#
#
#
# **A concrete illustration, using this course's own numbers:** training the CNN you'll build in Colab 2 on one subject's data might take a couple of minutes on a laptop's CPU. Training and properly cross-validating it across all 28 subjects — or running the Module 5 hyperparameter sweep across several architectures — could easily take 10–20 times longer serially. That's the difference between a 5-minute laptop job and a job that either ties up your laptop for over an hour, or finishes in a few minutes on FABRIC's GPU-enabled nodes instead. Multiply that gap by a real research project with hundreds of subjects instead of 28, and the case for moving up a tier stops being abstract.
#
#
#
# **Ask your AI tool:** "For a research project involving [describe your own project idea], estimate roughly how much slower it would run on a laptop's CPU compared to a single GPU, and explain what specifically about the computation makes GPUs faster for this kind of workload."

# %%
# 📝 Activity A.0 — Paste your AI conversation and your own short answer here:

# %% [markdown]
# > **Add to your Ladder document above:** write your own CI-Hardware rung, in your own words, citing at least one real number from the table above or your AI conversation.

# %% [markdown]
# ***
#
#
#
#
#
#
#
# ## 🖥️ Part A (Primer): CI Hardware/Software, Including Edge Computing
#
#
#
#
#
#
#
# ### Topic: The General Pattern for Accessing National Research Computing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Some research questions need more computing power than a laptop or Google Colab can provide. Getting access to that kind of power almost always follows the same general pattern, no matter which specific system you end up using: **create an account, get approved for a project, generate a security credential, and confirm you're connected.** FABRIC — a national research testbed — is this course's worked example, but the pattern transfers directly to your own institution's HPC cluster or any other system your research group uses. You'll provision and use a real FABRIC session starting in Colab 2.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ### 🧭 Activity A.1 — Understanding Your Compute Environments
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Before requesting any real computing resources, it's worth knowing what you're actually choosing between. Three environments come up throughout this course:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# | Environment | What it actually is | Reaches FABRIC directly? | Best for |
#
#
#
#
#
#
#
# |---|---|---|---|
#
#
#
#
#
#
#
# | **Google Colab** | A free, hosted Jupyter notebook in your browser. Nothing to install; nothing persists on its own. | ❌ No dependable network path into a research testbed | Quick, shareable, zero-install work |
#
#
#
#
#
#
#
# | **A testbed's own JupyterHub** (e.g., FABRIC's) | A multi-user Jupyter deployment the testbed itself runs, inside its own network, with its toolkit and your credentials already configured. | ✅ Yes — that's the whole point of running it there | Provisioning, running, and releasing real computing sessions |
#
#
#
#
#
#
#
# | **VSCode (with Remote-SSH)** | A full code editor that can open a direct terminal/file connection to a remote machine, including a running compute node. | ✅ Yes, once you already have a running session to connect to | Serious day-to-day development once a session already exists |
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Ask your AI tool:** copy the prompt below, filling in your own research area.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# > "I just learned about three computing environments: Google Colab (hosted, zero-install, no direct HPC access), a research testbed's own JupyterHub (pre-configured, reaches the testbed's compute directly), and VSCode with Remote-SSH (a full editor that connects to an already-running remote session). My research involves [describe your data/analysis needs]. Which of these three would I actually reach for at each stage of my work, and why?"

# %%
# 📝 Activity A.1 — Paste your AI conversation and your own short answer here:

# %% [markdown]
# ### 🧭 Activity A.2 — The CI-Software Abstraction Ladder: From Machine Code to Vibe Coding
#
#
#
# Every AI Prompt Challenge in this course sits at the current endpoint of a real, decades-long historical progression: `machine code (binary) → assembly → compiled high-level languages (Fortran, C, 1950s–70s) → interpreted/scripting languages with automatic memory management (Python) → frameworks and libraries → vibe coding, today`. Each step handed a layer of low-level detail over to a machine, freeing the human to work at a higher level of intent.
#
#
#
# **A number worth knowing, not just a vibe:** a 2026 security study testing six frontier LLMs found that **25.1% of AI-generated code samples contained a confirmed, exploitable vulnerability** — a real, measured number, not a guess, and a direct argument for why the "evaluate what the AI gives you" habit this whole course is built around isn't optional.
#
#
#
# **A useful piece of history:** when compilers first appeared in the 1950s, experienced assembly programmers were skeptical of them for the same reasons some developers are skeptical of AI-assisted coding today — trusting a layer of abstraction you didn't write yourself. This isn't a new anxiety unique to AI; it's a recurring pattern every time computing adds a layer of abstraction.

# %%
# 📝 Activity A.2 — no AI prompt needed here; just add to your Ladder document below.

# %% [markdown]
# > **Add to your Ladder document above:** write your own CI-Software rung, citing the 25.1% vulnerability statistic or a number you find yourself researching AI-assisted coding.

# %% [markdown]
# ### ✍️ Part A Reflection
#
#
#
# *Double-click this cell to write your response.*
#
#
#
#
#
#
#
# * **What I observed:** Which environment did your AI conversation point you toward, and did that match your own intuition beforehand?
#
#
#
# * **Connecting to key concepts:** Connects to **FABRIC [Concept 1](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#fabric1) (Research Testbed), [Concept 19](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#fabric19) (Project Membership), and [Concepts 16–18](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#fabric16) (Compute Environments)**. Why can't Colab reach a research testbed's compute directly, even though it can run the same Python code?
#
#
#
#
#
#
#
# ***
#
#
#
# ## 💻 Part B (Build 1 of 2): Data Acquisition and Statistical Analysis
#
#
#
# ### Topic: A Real Single-Subject EEG Dataset
#
#
#
#
#
#
#
# You'll work with a real dataset: EEG signals recorded from a participant (S01) playing four emotionally different computer games — boring, calm, horror, funny.
#
#
#
#
#
#
#
# ### 🧭 Module 1 — Data Acquisition
#
#
#
#
#
#
#
# > Copy the code block below into your notebook, then copy this prompt into your AI tool:
#
#
#
# >
#
#
#
# > "Write a function `get_data(data_config)` that takes the `DATA_CONFIG` below, reads each file with pandas using urls from the values, adds a game identifier to each file (the corresponding key), concatenates all dataframe into one and returns it."

# %%
import numpy as np







import pandas as pd







import matplotlib.pyplot as plt















DATA_CONFIG = {







    "boring": "https://github.com/cyneuro/CI-BioEng-Class/raw/refs/heads/main/emotion_recognition/data/S01G1AllChannels.csv",







    "calm": "https://github.com/cyneuro/CI-BioEng-Class/raw/refs/heads/main/emotion_recognition/data/S01G2AllChannels.csv",







    "horror": "https://github.com/cyneuro/CI-BioEng-Class/raw/refs/heads/main/emotion_recognition/data/S01G3AllChannels.csv",







    "funny": "https://github.com/cyneuro/CI-BioEng-Class/raw/refs/heads/main/emotion_recognition/data/S01G4AllChannels.csv"







}

# %%
# 💻 Module 1 — Paste your AI-generated get_data() code here:

# %%
data = get_data(DATA_CONFIG)







data.head()

# %% [markdown]
# ### 🧭 Module 2 — Data Analysis
#
# > "Assume the columns of my dataframe are recordings from individual electrodes (AF3 to T8), with the identifier saved in the 'game' column. Write a function `run_anova(data)` that takes each electrode in the data separately (AF3 to T8) and runs a simple ANOVA between the games. Print out the composite significance results table."
#
# **Now make it harder — two additions the base prompt above doesn't ask for:**
#
# **Addition A — Multiple-comparisons correction.** You're running 14 separate ANOVAs, one per electrode. Running that many tests inflates the chance of a false positive purely by chance, even if nothing real is happening. Ask your AI tool: *"Extend `run_anova()` to apply a Bonferroni or FDR (Benjamini-Hochberg) correction across all 14 electrode p-values, and report both the corrected and uncorrected significant-electrode counts side by side."* Compare the two counts — if they differ, that difference is the actual, quantified cost of not correcting for multiple comparisons.
#
# **Addition B — Effect size.** A significant p-value alone doesn't tell you whether a difference is large enough to matter. Ask your AI tool: *"For each electrode, also compute an effect size (Cohen's d for the largest pairwise game comparison, or eta-squared for the overall ANOVA) alongside the p-value."* Find at least one electrode that is statistically significant but has a small effect size — and write one sentence explaining, in your own words, what that combination actually means for interpreting your results.

# %%
# 💻 Module 2 — Paste your AI-generated run_anova() code here:

# %%
anova_result = run_anova(data)

# %% [markdown]
# ### ✍️ Part B Reflection
#
#
#
#
#
#
#
# *Double-click this cell to write your response.*
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# * **What I observed:** How many electrodes came out statistically significant? Does that match what you'd expect from four emotionally different games?
#
#
#
#
#
#
#
# * **Connecting to key concepts:** Connects to **Certification Concept 3** — why analysis is kept separate from data loading and visualization. Explain, in your own words, why `run_anova()` doesn't know or care how `get_data()` fetched its input.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
#
#
#
#
#
# > ## ✅ Colab 1-1 Submission Checkpoint (due end of Week 1)
#
#
#
#
#
#
#
# > Submit through Module 2 and its reflection — the Primer activity and data acquisition + statistical analysis.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
#
#
#
#
#
# ## 📊 Part C (Build 2 of 2): Visualizing and Documenting Your Results
#
#
#
#
#
#
#
# ### Topic: Turning Statistics Into a Reproducible Record
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ### 🧭 Module 3 — Visualizing Results
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# > "Now write a function `plot_results()` that takes a dataframe in this format and makes a seaborn histogram showing averages and SEMs. It should also take the `anova_result` table from the previous step and indicate significance with stars and no significance with NS."

# %%
# 💻 Module 3 — Paste your AI-generated plot_results() code here:

# %%
plot_results(data, anova_result)

# %% [markdown]
# ### 🧭 Module 4 — Documenting Research
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# > "Assume the anova table from above is saved in the `anova_result` variable. Write a documentation logging function `document_research` that creates a pandas dataframe with the following columns: current date, number of significant (p < 0.05) electrodes, and returns it."

# %%
# 💻 Module 4 — Paste your AI-generated document_research() code here:

# %%
document_research(anova_result)

# %% [markdown]
# ### 🧭 Embedded Playground
#
# **Task 1.** Hypothesize which two game types are likely to produce the most different emotional responses, then re-run the analysis using only those two conditions.
#
# **Task 2 (revised — a real design decision, not just "add something").** Preprocessing EEG data before analysis isn't optional in real research, but *how* you preprocess it is a genuine, contested choice with trade-offs, not a single correct recipe. Ask your AI tool to explain the difference between two documented re-referencing approaches — **average reference** (subtract the mean across all electrodes) and **linked-mastoid reference** (subtract the average of two specific reference electrodes) — including at least one real trade-off each. Then implement **one** of the two, and write 3–4 sentences justifying *why* you chose that one for this specific dataset and question, not the other. "I picked whichever was easier to code" is not an acceptable justification here — the point is defending a real methodological choice.

# %%
# 🧭 Embedded Playground — run your full pipeline here







data = get_data(DATA_CONFIG)







anova_result = run_anova(data)







plot_results(data, anova_result)







document_research(anova_result)

# %% [markdown]
# ### ✍️ Part C Reflection
#
#
#
#
#
#
#
# *Double-click this cell to write your response.*
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# * **What I observed:** What did Task 1 and Task 2 change about your results? Did narrowing to two conditions or adding preprocessing shift which electrodes were significant?
#
#
#
#
#
#
#
# * **Connecting to key concepts:** Connects to **Certification Concept 5** — why a workflow saves a small log (like your `document_research()` output) alongside results. What would you lose if you skipped this step and only kept the plot?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
#
#
#
#
#
# > ## ✅ Colab 1-2 Submission Checkpoint (due end of Week 2, combined)
#
#
#
#
#
#
#
# > Submit the complete notebook (Parts A, B, and C, all reflections, both Embedded Playground tasks). This is the full Colab 1 deliverable and earns the CI hardware/software (including edge computing) microcredential.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
#
#
#
#
#
# ## 📑 What Comes Next
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Colab 2 scales this same pipeline from one participant to all 28 — and this time you provision and use a real FABRIC computing session yourself, training a neural network instead of running per-electrode statistics.

# %% [markdown]
# ***
#
# ## 🎯 Foundational Concepts: This Colab's Microcredential Targets
#
#
#
# This section is the actual outcome of Colab 1's microcredential — not an afterthought at the end. Below are the 12 core concepts this Colab is built to teach: Software Drift, Stage Independence, FAIR-Compliant Data, Provenance/Documentation Logging, Deterministic Workflows, Research Testbed, Google Colab, Testbed JupyterHub, VSCode Remote-SSH, Project Membership, the CI-Hardware Tier Ladder, and the CI-Software Abstraction Ladder — the last two are also the first two rungs of your Cumulative Microcredential Ladder from Part A.
#
#
#
# For each one: read the short resource, run the code if there is any, then **go find and answer a real practice question about it from somewhere other than this course** — a textbook companion site, a university's open courseware quiz, a MOOC's practice set, anywhere. These 12 concepts are exactly what the Target Questions at the end of this Colab — and later, the quizzes and Final — will test.

# %% [markdown]
# ### Concept 1 — Software Drift
#
#
#
#
#
#
#
# **Resource:** A workflow that runs correctly today can fail months later even with unchanged code and data, because one or more of the libraries it depends on quietly updated in the meantime. This is <em>software drift</em> — the same script, a different result, because the ground it's standing on shifted.

# %%
def old_behavior(x):



    return x // 2          # integer (floor) division -- an older library's default







def new_behavior(x):



    return x / 2            # true division -- the same call, a newer library's default







print("Old library:", old_behavior(5))   # 2    (drifted!)



print("New library:", new_behavior(5))   # 2.5

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *software versioning or reproducibility* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 2 — Stage Independence
#
#
#
#
#
#
#
# **Resource:** A well-designed workflow keeps its stages — obtaining data, analyzing it, visualizing it, documenting it — independent of one another. <code>run_anova()</code> in this Colab doesn't know or care whether <code>get_data()</code> fetched its input from a URL, a local file, or a simulated array.

# %%
import pandas as pd



from scipy import stats







def run_anova_demo(data):



    groups = [g["value"].values for _, g in data.groupby("condition")]



    f_stat, p_val = stats.f_oneway(*groups)



    return f_stat, p_val







from_a_url = pd.DataFrame({"condition": ["a","a","b","b"], "value": [1,2,5,6]})



from_a_simulation = pd.DataFrame({"condition": ["a","a","b","b"], "value": [10,11,2,3]})



print(run_anova_demo(from_a_url))



print(run_anova_demo(from_a_simulation))

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *modular design or separation of concerns* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 3 — FAIR-Compliant Data
#
#
#
#
#
#
#
# **Resource:** "FAIR" data is organized so others can <b>F</b>ind it, <b>A</b>ccess it, and <b>C</b>ombine/<b>I</b>nteroperate and <b>R</b>euse it. A dataset with a clear naming scheme, a documented format, and an open license is FAIR; a dataset that's just "a folder someone emailed you" usually isn't.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *FAIR data principles* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 4 — Provenance/Documentation Logging
#
#
#
#
#
#
#
# **Resource:** A workflow that saves a small log alongside its results — what date it ran, what settings were used, how many results came out significant — lets you (or anyone else) reconstruct exactly what happened later. Without this, reproducing a result means guessing.

# %%
from datetime import date



import pandas as pd







def document_research(anova_result):



    n_sig = int(anova_result["significant"].sum())



    return pd.DataFrame([{"date": date.today().isoformat(), "n_significant": n_sig}])

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *research provenance or data logging* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 5 — Deterministic Workflows
#
#
#
#
#
#
#
# **Resource:** A deterministic workflow, given the exact same input and settings, always produces the exact same output. This is what lets a collaborator trust that re-running your analysis will get them the same conclusions you got.

# %%
import numpy as np



rng1 = np.random.default_rng(seed=42)



rng2 = np.random.default_rng(seed=42)



print(rng1.normal(size=3))



print(rng2.normal(size=3))  # identical -- the fixed seed makes this deterministic

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *deterministic vs. stochastic computing* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 6 — Research Testbed
#
#
#
#
#
#
#
# **Resource:** FABRIC is a shared, national-scale research testbed — a pool of computing resources that many researchers request time on, rather than something any one person owns outright. This is why access requires an account, project approval, and a security credential, unlike a personal laptop.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *national research computing testbeds* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 7 — Google Colab (Compute Environment)
#
#
#
#
#
#
#
# **Resource:** Google Colab is a free, hosted Jupyter notebook in your browser — nothing to install, easy to share, but with no dependable network path into a research testbed like FABRIC.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *cloud notebook environments* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 8 — Testbed JupyterHub
#
#
#
#
#
#
#
# **Resource:** A research testbed's own JupyterHub is a multi-user Jupyter deployment the testbed itself runs, inside its own network, with credentials already configured — the only one of the three compute environments in this course that reaches FABRIC's compute directly.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *JupyterHub deployments for research computing* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 9 — VSCode with Remote-SSH
#
#
#
#
#
#
#
# **Resource:** VSCode with Remote-SSH is a full code editor that opens a direct terminal/file connection to an already-running remote machine — the natural upgrade once a FABRIC session already exists, for serious day-to-day development.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *remote development environments (Remote-SSH, remote containers)* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 10 — Project Membership
#
#
#
#
#
#
#
# **Resource:** On FABRIC (and most shared research computing), an account alone isn't enough — you must be added to an approved project before the system will let you request any resources. This is a separate step from account creation.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *research computing account/project approval processes* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 11 — CI-Hardware Tier Ladder
#
#
#
# **Resource:** From a laptop (~8–16 cores, 16–32 GB RAM) to a national resource like FABRIC (a testbed spanning dozens of sites) to ACCESS (coordinating multiple national supercomputers at petaflop scale), each tier up is a real, quantifiable jump in capability — not just "more computer." See Activity A.0 for the full table and this course's own CNN-training example.

# %%
# 🔍 Find-and-Practice: search for a practice question about HPC tiers or cluster computing from an external source. Paste it, your answer, and the source URL here:

# %% [markdown]
# ### Concept 12 — CI-Software Abstraction Ladder
#
#
#
# **Resource:** From machine code to assembly to compiled languages to Python to vibe coding — each step abstracted away a layer of low-level detail. The 25.1% figure from Activity A.2 (confirmed exploitable vulnerabilities in AI-generated code, 2026 study) is this ladder's most important current number: abstraction doesn't remove the need to verify.

# %%
# 🔍 Find-and-Practice: search for a practice question about programming language abstraction or AI code security from an external source. Paste it, your answer, and the source URL here:

# %% [markdown]
# ***
#
# ## 🎯 Target Questions
#
#
#
# These are the questions the 10 concepts above prepare you for. They're the same concepts — and often close to the same format — as what appears on the quizzes and Final. **Each question has exactly TWO correct answers**, matching the actual quiz format.
#
#
#
# No answer key is provided here on purpose. Work out your answer, then use an AI tool to check your reasoning and confirm or correct it — that verification step is itself part of the skill this course is built around.
#
#
#
# **1.** Which TWO are the most likely causes of software drift?
#
# A) A library updated in the meantime, changing behavior.
#
# B) The workflow depends on an implicit default that was never pinned to a specific version.
#
# C) The data silently corrupted itself over time.
#
# D) The computer's processor slowed down permanently.
#
# E) The internet connection degraded the code.
#
#
#
# **2.** Which TWO describe what stage independence gives you?
#
# A) Independent stages can each be updated or replaced without disrupting the rest.
#
# B) You can test one stage in isolation without running the entire pipeline.
#
# C) Code is optimized to run only on cloud computers.
#
# D) Algorithms require a password before starting.
#
# E) Workflows publish results directly to websites.
#
#
#
# **3.** Which TWO does "FAIR" data actually stand for?
#
# A) Findable and Accessible.
#
# B) Interoperable and Reusable.
#
# C) Fast and Inexpensive.
#
# D) Automated and Regulated.
#
# E) Free and Immutable.
#
#
#
# **4.** Which TWO are true about a workflow's documentation log?
#
# A) It records details like the run date and number of significant results.
#
# B) It lets someone reconstruct what happened without guessing.
#
# C) It replaces the need for version control entirely.
#
# D) It is only useful if the workflow fails.
#
# E) It must be handwritten, never generated by code.
#
#
#
# **5.** Which TWO describe a deterministic workflow?
#
# A) The same input and settings always produce the same output.
#
# B) It lets a collaborator trust that re-running it gets the same conclusions.
#
# C) It guarantees the workflow runs faster than a non-deterministic one.
#
# D) It only applies to workflows that don't use random numbers at all.
#
# E) It means the code never needs to be tested.
#
#
#
# **6.** Which TWO describe FABRIC as a research testbed?
#
# A) It's a shared, national-scale pool of computing resources.
#
# B) Access requires an account, project approval, and a security credential.
#
# C) Anyone can use it immediately with no approval process.
#
# D) It's owned outright by a single research lab.
#
# E) It requires no more setup than a personal laptop.
#
#
#
# **7.** Which TWO correctly describe Google Colab as a compute environment?
#
# A) It's free and hosted, with nothing to install.
#
# B) It has no dependable network path into a research testbed like FABRIC.
#
# C) It's the fastest way to reach FABRIC's compute directly.
#
# D) It requires a FABRIC project membership to use at all.
#
# E) It cannot run any Python code.
#
#
#
# **8.** Which TWO describe a testbed's own JupyterHub?
#
# A) It's a multi-user Jupyter deployment the testbed itself runs.
#
# B) It reaches the testbed's compute directly, unlike Colab.
#
# C) It requires no credentials of any kind.
#
# D) It is identical in every way to Google Colab.
#
# E) It cannot be used for FABRIC work.
#
#
#
# **9.** Which TWO describe VSCode with Remote-SSH in this context?
#
# A) It's a full code editor connected to an already-running remote session.
#
# B) It's a natural upgrade for serious day-to-day development once a session exists.
#
# C) It provisions a new FABRIC session on its own.
#
# D) It replaces the need for any FABRIC account.
#
# E) It only works with local files, never remote ones.
#
#
#
# **10.** Which TWO describe FABRIC project membership?
#
# A) You must be added to an approved project before requesting resources.
#
# B) It's a separate step from simply having a personal account.
#
# C) It happens automatically the moment you sign up.
#
# D) It's the same thing as generating a security credential.
#
# E) It only applies to advanced users, not beginners.
#
#
#
# **11.** Which TWO statements accurately reflect the scale jump from a laptop to a national resource?
#
#
#
# A. A laptop typically has around 8–16 CPU cores, while ACCESS coordinates multiple national supercomputers at a collective petaflop scale.
#
# B. An institutional HPC cluster typically offers hundreds to thousands of cores shared campus-wide, more than a single departmental server.
#
# C. A laptop and FABRIC offer functionally identical computing capability.
#
# D. Moving up a hardware tier never actually changes how long a computation takes.
#
# E. A departmental server is typically larger in scale than an entire national resource.
#
#
#
# **12.** Which TWO statements accurately describe the CI-software abstraction ladder and its risks?
#
#
#
# A. Each step (assembly → compiled languages → Python → vibe coding) abstracted away a layer of low-level detail from the human programmer.
#
# B. A 2026 study found roughly a quarter of AI-generated code samples contained a confirmed, exploitable vulnerability.
#
# C. Abstraction has made verifying code correctness completely unnecessary.
#
# D. Skepticism toward a new layer of abstraction is a phenomenon unique to AI-assisted coding, with no historical precedent.
#
# E. Compiled languages were adopted with zero resistance from assembly-era programmers.

# %% [markdown]
# ***
#
#
#
# ## ✍️ Now It's Your Turn: Write 10 Target Questions of Your Own
#
#
#
#
#
#
#
# You've worked through 10 concept resources, hunted down external practice questions for each, and answered the 10 official Target Questions above. Now flip the process: write **10 of your own** target-style questions covering this Colab's material.
#
#
#
#
#
#
#
# Your questions can be:
#
#
#
# - Harder or more specific versions of the concepts above,
#
#
#
# - Questions about something this Colab covered that wasn't in the official 10,
#
#
#
# - Questions inspired by whatever you found during your Find-and-Practice research.
#
#
#
#
#
#
#
# Use the same two-answer-select format (5 options, exactly 2 correct) or a short conceptual question — whichever fits the idea better. Include the correct answer(s) and a one-sentence explanation for each.
#
#
#
#
#
#
#
# **Why this matters:** writing a good test question requires understanding the material more deeply than just answering one — you have to know not just what's true, but what's *plausibly wrong* (the distractors). This is also genuinely useful beyond your own studying: your best questions may get folded into a future semester's quiz bank, the same way the Advanced Explorations Library's Field-Scan Challenge (Option E) uses student proposals to keep that material current.

# %%
# ✍️ Write your 10 original questions, answers, and explanations here:

# %% [markdown]
# ***
#
# ## 📖 Reference Guide: Concepts Used in Colab 1
#
#
#
# **From the master 50:** [Concept 3](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#q3) (Stage Independence), [Concept 5](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#q5) (Provenance/Documentation Logging).
#
#
#
# **From FABRIC's 19:** [Concept 1](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#fabric1) (Research Testbed), [Concept 19](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#fabric19) (Project Membership — corrected from an earlier mistaken citation of Concept 8), [Concepts 16–18](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#fabric16) (Compute Environments: Colab, testbed JupyterHub, VSCode).
#
#
#
# ***
#
# ## ✅ Self-Check: What Did You Learn?
#
#
#
# | Concept Area | Concept | Where You Demonstrated It |
#
# |---|---|---|
#
# | Computing | Concept 3 — Separating analysis from loading/visualization | [ Enter Module ID ] |
#
# | Computing | Concept 5 — Why workflows log their own results | [ Enter Module ID ] |
#
# | Compute Environments | Concepts 16–18 — Colab vs. testbed JupyterHub vs. VSCode | [ Enter Activity ID ] |
#
# | Statistics | Per-electrode ANOVA across conditions | [ Enter Module ID ] |
#
#
#
# **From the Cumulative Microcredential Ladders:** [CI-Hardware Tier Ladder](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#ladder1), [CI-Software Abstraction Ladder](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#ladder2).
