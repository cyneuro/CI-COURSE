# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cyneuro/CI-COURSE/blob/main/Colab_2_Scaling_to_a_Cohort.ipynb)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# # 🧭 Colab 2: Processing Multi-Subject Datasets with High-Performance Computing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ## Training a Neural Network on FABRIC Across All 28 Subjects
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ### Scientific Workflows for Brain and Behavioral Research
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ### National Science Foundation Supported Learning Initiative (Award No. OAC-2417875)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# #### Semester Course — Colab 2 of 5 (Weeks 3–4)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ## Overview
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# You extend Colab 1's single-subject workflow to the full 28-subject EEG emotion-recognition dataset — and since a dataset and model of this size are impractical on a laptop, you do the work on **FABRIC**, the national research testbed. Rather than per-electrode statistics, this Colab trains a convolutional neural network (CNN) that learns to predict which game a participant was playing directly from their EEG recording.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# This is also where "vibe coding" — this Colab's Primer topic — does real work for you: you'll use it to set up your FABRIC environment, and separately to teach yourself a second CI platform (CloudLab or NSG) with no prompt provided at all.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Split into two submissions:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# - **Colab 2-1** (end of Week 3): environment setup and full-cohort data acquisition (including a real messy-data debugging exercise).
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# - **Colab 2-2** (end of Week 4, combined): training the CNN, visualizing results, and documenting the run.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ## 📋 Set Up Your Profile

# %%
# PROFILE SETUP















student_name = "Your Name"















institution = "Your University/Organization"















team_name = "Your Team Name"















print(f"✅ Notebook initialized for {student_name} ({institution}) — Team {team_name}")

# %% [markdown]
# ***
#
#
#
# ## 🪜 Your Cumulative Microcredential Ladder — Colab 2 Additions
#
#
#
#
#
#
#
# Copy your Ladder document forward from Colab 1. This Colab adds two new rungs: two more CI-Hardware tiers (ACCESS, NAIRR), and the starter rung of a new ladder — AI/Agentic — which gets fully developed in Colab 4. As always: every rung needs a real number.

# %% [markdown]
# ***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ## 🤖 Part A (Primer): Agentic AI / Vibe Coding for Neuro-Workflows
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ### 🧭 Activity A.1 — Setting Up an Environment on FABRIC
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# You provisioned FABRIC access back in Colab 1's Primer conceptually — now you'll actually use a session. Copy this prompt into your AI tool:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# > "Give me commands I can use in the ubuntu terminal to (1) install anaconda, (2) create a conda environment, (3) activate that environment, (4) install numpy, pandas, matplotlib, pytorch (GPU-compatible)."

# %%
# 💻 Activity A.1 — Paste your AI-generated FABRIC environment-setup commands here:

# %% [markdown]
# ### 🧭 Activity A.2 — Vibe-Coding HW: Exploring a New CI Platform on Your Own
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Every activity so far has given you a starting prompt to copy and refine. This one doesn't — it's the real test of vibe coding as a self-learning tool.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# FABRIC isn't the only national research computing platform researchers use. Two others come up often in neuroscience and CI work:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# * **CloudLab** — a testbed for experimenting with cloud computing infrastructure itself (networking, storage, virtualization), often used when a project needs more control over the underlying hardware/network setup than FABRIC provides.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# * **Neuroscience Gateway (NSG)** — a science gateway built specifically for neuroscience researchers, giving access to high-performance computing for large-scale brain modeling and data analysis without needing to manage the underlying infrastructure directly.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# *(Globus is a third tool worth knowing, though it does a different job: it's used for moving large research datasets reliably between institutions and computing resources, rather than for requesting compute time itself. Colab 3 has its own self-directed exploration activity for Globus.)*
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Task:** Your team, choose **one** of CloudLab or NSG (your instructor may assign one instead). Without a starting prompt from this notebook, use an AI tool to teach yourself:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1. What the platform is for, and how it's different from FABRIC.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2. How a researcher actually requests and accesses computing resources on it.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3. Write (and run, if you have access; otherwise write as clearly-commented pseudocode) a short script that would request a basic compute session on your chosen platform.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Since there's no prompt to copy this time, **keep a short log of your own prompt iterations**: what you asked first, what came back wrong or incomplete, and how you refined the question.

# %%
# 💻 Activity A.2 — Paste your AI-generated CloudLab/NSG exploration code here, and your prompt-iteration log:

# %% [markdown]
# ### 🧭 Activity A.3 — CI-Hardware Ladder: Beyond FABRIC (ACCESS and NAIRR)
#
#
#
#
#
#
#
# FABRIC is one national resource, not the only one. **ACCESS** (formerly XSEDE) is the NSF's broader coordination ecosystem — it doesn't run one supercomputer, it coordinates *allocations* across multiple national supercomputing centers at once, collectively operating at a petaflop scale (quadrillions of operations per second). **NAIRR** (National AI Research Resource) is newer still — a national resource created specifically because AI workloads need GPU-heavy infrastructure most individual researchers can't access otherwise.
#
#
#
#
#
#
#
# **Ask your AI tool:** "For a research project that needs [describe your own project's compute needs], would ACCESS's broader multi-center ecosystem or NAIRR's AI-specific GPU resources be the better fit, and why? What's the actual difference between requesting a FABRIC allocation versus an ACCESS allocation?"

# %%
# 📝 Activity A.3 — Paste your AI conversation and your own short answer here:

# %% [markdown]
# > **Add to your Ladder document:** your CI-Hardware rungs for ACCESS and NAIRR, each with a real number or concrete distinction from FABRIC.

# %% [markdown]
# ### 🧭 Activity A.4 — AI/Agentic Ladder, Starter Rung: Classical ML → Generative AI
#
#
#
#
#
#
#
# The CNN you're about to build in Module 2 is **classical machine learning** — a model trained on labeled data to make one specific kind of prediction. The AI tool you've been vibe-coding with all semester is a completely different category: **generative AI**, a model trained to produce open-ended text, code, or other content in response to a prompt. Both are "AI," but they're not the same thing, and this course uses both simultaneously.
#
#
#
#
#
#
#
# This is the starter rung of a new ladder — AI/Agentic — that gets fully developed in Colab 4, including where the field is actually headed next (with real growth numbers, not just hype).

# %%
# 📝 Activity A.4 — no AI prompt needed; add your own rung to your Ladder document below.

# %% [markdown]
# > **Add to your Ladder document:** distinguish classical ML (your CNN) from generative AI (your AI coding assistant) in your own words.

# %% [markdown]
# ### ✍️ Part A Reflection
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# *Double-click this cell to write your response.*
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# * **What I observed:** How did the FABRIC environment-setup process (Activity A.1, prompt given) compare to the CloudLab/NSG exploration (Activity A.2, no prompt given)?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# * **Connecting to key concepts:** Connects to **Certification Concepts 6 and 7** (dedicated software environments; sharing your setup via an environment file) and the new AI/Agentic track's **Vibe Coding / AI-Assisted Coding** concept.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ## 💻 Part B (Build 1 of 2): Full-Cohort Data Acquisition
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ### Topic: Scaling to 28 Subjects, and a Real Debugging Exercise
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# We continue with the same EEG Emotion Recognition dataset, now acquiring data from all 28 subjects.

# %%
import kagglehub















import os































# Download from kaggle















path = kagglehub.dataset_download("wajahat1064/emotion-recognition-using-eeg-and-computer-games")















print("Dataset downloaded to:", path)































path = os.path.join(path,















                     "Dataset - Emotion Recognition data Based on EEG Signals and Computer Games",















                     "Database for Emotion Recognition System Based on EEG Signals and Various Computer Games - GAMEEMO",















                     "GAMEEMO"















                    )

# %% [markdown]
# ### 🧭 Module 1 — Building the Subject List
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The `subjects` variable should hold subject identifiers from the dataset (S01–S28). Design your own prompt with the AI to define this variable — there's no starting prompt here, since this one's a simple enough ask to write yourself.

# %%
# 💻 Module 1 — Paste your AI-generated subjects list code here:

# %%
print(len(subjects))

# %% [markdown]
# The functions below read data from a single subject and combine the resulting dataset into an array of size (subjects × game_types × channels × time). These are provided for you — no AI prompt needed.

# %%
import numpy as np















import pandas as pd































def read_subject(subject, path):















    assert len(os.listdir(path)) == 4































    subject_recordings = []















    for game_idx in range(4):















        # Read channel x time data















        csv_filename = f'{subject}G{game_idx + 1}AllChannels.csv'















        df = pd.read_csv(os.path.join(path, csv_filename))















        df.drop("Unnamed: 14", axis = 1, inplace = True)































        # Shape into a channels x time array















        subject_recordings.append(df.to_numpy().T)































    # Shape into game_types x channels x time















    subject_recordings = np.stack(subject_recordings)































    return subject_recordings































def read_subjects(subjects, path):















    all_recordings = []















    for subject in subjects:















        subject_path = os.path.join(path, f"({subject})", "Preprocessed EEG Data", ".csv format")















        data = read_subject(subject, subject_path)















        all_recordings.append(data)































    # Subjects x game_types x channels x time















    all_recordings = np.stack(all_recordings)















    return all_recordings

# %%
data = read_subjects(subjects, path)

# %% [markdown]
# ### 🧭 Module 1b — A Real Messy-Data Debugging Exercise
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# As you just saw, there's an error when reading data for one of the subjects. This is a genuine data-quality issue, not a planted bug for teaching purposes — real datasets from 28 different recording sessions are rarely perfectly uniform.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Design a prompt to list the contents of the problem subject's directory and compare the contents with another subject's (e.g., S01). What's the problem?

# %%
# 💻 Module 1b — Paste your AI-generated directory-comparison code here (compare the problem subject to S01):

# %% [markdown]
# Once you've diagnosed the issue, prompt AI to modify the list of subjects to exclude the problem subject (but still include the other 27).

# %%
# 💻 Module 1b — Paste your AI-generated updated subjects list here:

# %%
data = read_subjects(subjects, path)































# Subjects x game_types x channels x time















print(data.shape)

# %% [markdown]
# ### ✍️ Part B Reflection
#
#
#
#
#
#
#
# *Double-click this cell to write your response.*
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# * **What I observed:** What exactly was different about the problem subject's directory? Was this the kind of issue you could have caught by reading error messages alone, or did you need to actually compare directory contents?
#
#
#
#
#
#
#
# * **Connecting to key concepts:** Connects to **Certification Concept 39** (error-handling safeguards). At single-subject scale (Colab 1) this kind of issue wouldn't have surfaced at all — explain why cohort scale makes messy data close to inevitable.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
#
#
#
#
#
# > ## ✅ Colab 2-1 Submission Checkpoint (due end of Week 3)
#
#
#
#
#
#
#
# > Submit through the Part B reflection — the vibe-coding Primer (FABRIC setup + CloudLab/NSG exploration) and full-cohort data acquisition, including the debugging exercise.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
#
#
#
#
#
# ## 🧠 Part C (Build 2 of 2): Training, Visualizing, and Documenting
#
#
#
#
#
#
#
# ### Topic: A Real CNN on Real Multi-Subject Data
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ### 🧭 Module 2 — Training an ML Model (Harder Version — You Design the Architecture)
#
#
#
# We'll train a convolutional neural network (CNN) to predict the game type from the temporal data across channels, for all available subjects. Unlike Colab 1's prompts, this one deliberately does **not** hand you a fully-specified architecture — you have to make and justify real design decisions.
#
#
#
# > "I am working with a dataset of size subjects x conditions x channels x time, my actual shape is (27, 4, 14, 38252). Treat each subject x condition as a separate sample, with the CNN's 1D convolutions running across time and the first layer taking 14 channels as input. Beyond that starting constraint, propose a specific 1D CNN architecture (number of layers, kernel sizes, channel counts, pooling) and explain why each choice is reasonable given this data's shape — don't just give me 'a simple CNN.'"
#
#
#
# **Before you accept the AI's proposed architecture, answer this yourself:** why did it pick the kernel sizes it picked, given that your input is 38,252 timesteps long? What would happen to training time and memory if you doubled every channel count? Write 2–3 sentences of your own reasoning — if you can't explain a design choice the AI made, that's a sign to ask a follow-up question, not to accept it as-is.
#
#
#
# **Also required — replace the single fixed validation split with k-fold cross-validation.** The original single 24-subject-train / 3-subject-validation split means your reported accuracy depends heavily on which 3 subjects happened to land in that validation set. Ask your AI tool: "Instead of one fixed train/validation split, implement 5-fold cross-validation across the 27 subjects, training and validating 5 separate times with different subjects held out each time. Report the mean and standard deviation of validation accuracy across all 5 folds, not just a single number." A high standard deviation across folds is itself a meaningful, reportable finding — it means your model's performance is unstable depending on which subjects it happens to see, which a single train/validation split would have completely hidden from you.

# %%
# 💻 Module 2 — Paste your AI-generated CNN training code here:

# %% [markdown]
# ### 🧭 Module 3 — Visualizing Results
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Design a prompt to plot the saved train and validation losses and accuracies.

# %%
# 💻 Module 3 — Paste your AI-generated visualization code here:

# %% [markdown]
# ### 🧭 Module 4 — Documenting Research
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Design a prompt to save the resulting train and validation losses and accuracies in a `.csv` file.

# %%
# 💻 Module 4 — Paste your AI-generated documentation code here:

# %% [markdown]
# ### 🧭 Module 5 — Additional Prompt Challenges
#
#
#
# **Challenge 5 (Confusion Matrix) is now required, not optional — the rest remain optional if time allows.**
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1. **Beat the Baseline:** Use AI to modify the CNN architecture (layers, kernel sizes, channels, pooling) and improve validation accuracy.
#
#
#
#
#
#
#
# 2. **Try Different Optimizers:** Replace Adam with SGD, RMSprop, or AdamW. Compare convergence speed and final accuracy.
#
#
#
#
#
#
#
# 3. **Learning Rate Tuning:** Implement a learning rate scheduler (StepLR, CosineAnnealingLR, ReduceLROnPlateau) and see whether it helps.
#
#
#
#
#
#
#
# 4. **Normalization Challenge:** Z-score normalize the EEG channels using only the training subjects and compare results.
#
#
#
#
#
#
#
# 5. **Confusion Matrix (REQUIRED):** Compute and visualize a confusion matrix for the held-out subjects. Then write 2–3 sentences: which two conditions are most frequently confused with each other, and does that pairing make intuitive sense given what the four game conditions actually are (boring, calm, horror, funny)? A model confusing "horror" and "funny" tells you something different than one confusing "calm" and "boring."

# %%
# 💻 Module 5 (optional) — Paste any additional prompt-challenge code here:

# %% [markdown]
# ### ✍️ Part C Reflection
#
#
#
#
#
#
#
# *Double-click this cell to write your response.*
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# * **What I observed:** How did your model's validation accuracy compare to random chance (25%, given 4 classes)? If you attempted any Module 5 challenges, what changed?
#
#
#
#
#
#
#
# * **Connecting to key concepts:** Connects to **[Concept 26](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#q26), [Concept 27](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#q27)** (speedup factor, parallel bottleneck), and Track B's **[CPU vs. GPU](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackB16)**. Why does training a CNN on 27 subjects' worth of EEG data specifically benefit from FABRIC rather than a laptop?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
#
#
#
#
#
# > ## ✅ Colab 2-2 Submission Checkpoint (due end of Week 4, combined)
#
#
#
#
#
#
#
# > Submit the complete notebook (Parts A, B, and C, all reflections). This is the full Colab 2 deliverable and earns the agentic AI/vibe-coding microcredential.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
#
#
#
#
#
#
#
# ## 📑 What Comes Next
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Colab 3 goes deeper into FABRIC's resource-management side: Slurm-style job scheduling and running a brain-circuit model across multiple distributed nodes at once.

# %% [markdown]
# ***
#
#
#
# ## 🎯 Foundational Concepts: This Colab's Microcredential Targets
#
#
#
#
#
#
#
# This section is the actual outcome of Colab 2's microcredential — not an afterthought at the end. Below are the 12 core concepts this Colab is built to teach: Dedicated Software Environments, Environment Files, Software Containers, Documenting Software Versions, Checksum Verification, Speedup Factor, Parallel Bottleneck, Per-Participant Error Isolation, CPU vs. GPU, Vibe Coding, ACCESS/NAIRR (CI-Hardware Ladder), and Classical ML vs. Generative AI (AI/Agentic Ladder starter rung).
#
#
#
#
#
#
#
# For each one: read the short resource, run the code if there is any, then **go find and answer a real practice question about it from somewhere other than this course** — a textbook companion site, a university's open courseware quiz, a MOOC's practice set, anywhere. These 12 concepts are exactly what the Target Questions at the end of this Colab — and later, the quizzes and Final — will test.

# %% [markdown]
# ### Concept 1 — Dedicated Software Environments
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Resource:** A dedicated environment (like a conda environment) keeps one project's package versions isolated from every other project on the same machine, so installing something for Project B can't silently break Project A.

# %%
# Illustrating why isolation matters (conceptually, not a live conda call)







project_A_requires = {"numpy": "1.24", "torch": "2.0"}







project_B_requires = {"numpy": "1.26", "torch": "2.2"}







print("Without isolation, only one of these version sets could be installed system-wide at a time.")

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *virtual environments or dependency isolation* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 2 — Sharing Environments via Environment Files
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Resource:** An environment file (e.g., `environment.yml` or `requirements.txt`) is a plain-text list of exactly which packages and versions a project needs — the thing you'd actually send a collaborator instead of a long list of manual install steps.

# %%
# Example environment.yml content







env_file_contents = """







name: eeg_env







dependencies:







  - python=3.10







  - numpy







  - pandas







  - pytorch







"""







print(env_file_contents)

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *environment.yml, requirements.txt, or reproducible environments* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 3 — Software Containers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Resource:** A container (Docker, Singularity) packages code, libraries, and even the operating system together, so a workflow runs identically on any machine — a stronger guarantee than an environment file alone, which only lists what's needed, not the full system underneath it.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *Docker or Singularity containers* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 4 — Documenting Software Versions
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Resource:** Recording exactly which software versions were used for a given result (not just "Python" but "Python 3.10.2, PyTorch 2.2.0") is what makes a claimed result checkable months or years later.

# %%
import sys







print("Python version used for this run:", sys.version)

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *software version documentation in research* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 5 — Checksum Verification
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Resource:** A checksum is a short fingerprint computed from a file's contents — if you download the same dataset twice and get different checksums, the file changed or got corrupted in transit, something a file size alone wouldn't necessarily catch.

# %%
import hashlib







data_v1 = b"subject data version 1"







data_v2 = b"subject data version 1 (corrupted)"







print("Checksum 1:", hashlib.md5(data_v1).hexdigest())







print("Checksum 2:", hashlib.md5(data_v2).hexdigest())

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *file checksums or data integrity verification* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 6 — Speedup Factor
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Resource:** If splitting work evenly across N processors cuts total runtime by a factor of N, that's called linear (ideal) speedup — real speedup is usually less than N because of coordination overhead.

# %%
serial_time = 100  # seconds







parallel_time = 25  # seconds using 4 cores







speedup = serial_time / parallel_time







print(f"Speedup factor: {speedup}x")

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *parallel speedup or Amdahl's Law* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 7 — Parallel Bottleneck
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Resource:** Adding more processors doesn't keep reducing runtime forever — at some point, the time spent coordinating and combining results from all the workers outweighs the time saved by adding another one.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *parallel computing bottlenecks or diminishing returns* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 8 — Per-Participant Error Isolation
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Resource:** When one subject's data is malformed in a 28-subject batch run, a well-designed workflow logs that one failure and continues processing the other 27, rather than the entire run crashing.

# %%
def process_subject(subject_id, subjects_with_errors):







    if subject_id in subjects_with_errors:







        print(f"[LOGGED ERROR] {subject_id} failed -- continuing with others.")







        return None







    return f"{subject_id}: processed successfully"















for s in ["S01", "S02", "S26"]:







    print(process_subject(s, subjects_with_errors={"S26"}))

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *error handling or fault isolation in batch processing* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 9 — CPU vs. GPU
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Resource:** A CPU handles complex, varied tasks sequentially across a few powerful cores; a GPU handles many simple, repetitive tasks in parallel across thousands of smaller cores — which is exactly the shape of the matrix math inside a CNN's convolution layers.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *CPU vs GPU computing or why deep learning uses GPUs* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 10 — Vibe Coding
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Resource:** Vibe coding means specifying your intent to an AI tool in plain language, then evaluating, correcting, and iterating on what it returns — rather than hand-writing every line yourself. The skill isn't typing code; it's judging whether the AI's answer is actually right for your specific problem.

# %% [markdown]
# **🔍 Find-and-Practice:** Search the web for a practice question about *vibe coding or AI-assisted software development* from a source that isn't this course. Paste the question, your answer, and the source URL below.

# %%
# 📝 Paste your found question, your answer, and the source URL here:

# %% [markdown]
# ### Concept 11 — ACCESS and NAIRR (CI-Hardware Ladder)
#
#
#
#
#
#
#
# **Resource:** ACCESS coordinates allocations across multiple national supercomputing centers at once — collectively petaflop-scale, not one machine. NAIRR is a newer, AI-specific national resource, created because AI workloads need GPU-heavy infrastructure at a scale most researchers can't access alone.

# %%
# 🔍 Find-and-Practice: search for a practice question about ACCESS, XSEDE, or national AI compute resources from an external source. Paste it, your answer, and the source URL here:

# %% [markdown]
# ### Concept 12 — Classical ML vs. Generative AI (AI/Agentic Ladder Starter)
#
#
#
#
#
#
#
# **Resource:** Your Colab 2 CNN is classical ML — trained on labeled data for one specific prediction task. Your AI coding assistant is generative AI — trained to produce open-ended output from a prompt. Same broad category ("AI"), fundamentally different jobs.

# %%
# 🔍 Find-and-Practice: search for a practice question distinguishing classical ML from generative AI from an external source. Paste it, your answer, and the source URL here:

# %% [markdown]
# ***
#
#
#
# ## 🎯 Target Questions
#
#
#
#
#
#
#
# These are the questions the 10 concepts above prepare you for. They're the same concepts — and often close to the same format — as what appears on the quizzes and Final. **Each question has exactly TWO correct answers**, matching the actual quiz format.
#
#
#
#
#
#
#
# No answer key is provided here on purpose. Work out your answer, then use an AI tool to check your reasoning and confirm or correct it — that verification step is itself part of the skill this course is built around.
#
#
#
#
#
#
#
# **1.** Which TWO describe what a dedicated software environment does?
#
#
#
# A) Isolates one project's package versions from every other project.
#
#
#
# B) Prevents installing something for one project from breaking another.
#
#
#
# C) Automatically fixes bugs in your code.
#
#
#
# D) Makes your code run on a GPU automatically.
#
#
#
# E) Requires no setup at all.
#
#
#
#
#
#
#
# **2.** Which TWO describe an environment file?
#
#
#
# A) A plain-text list of exactly which packages and versions a project needs.
#
#
#
# B) The thing you'd send a collaborator instead of manual install steps.
#
#
#
# C) A binary file that can't be read by humans.
#
#
#
# D) Something that only works on one specific operating system.
#
#
#
# E) A record of every line of code ever run.
#
#
#
#
#
#
#
# **3.** Which TWO are true about software containers?
#
#
#
# A) They package code, libraries, and the OS together.
#
#
#
# B) They make a workflow run identically on any machine.
#
#
#
# C) They are the same thing as an environment file.
#
#
#
# D) They only work for Python projects.
#
#
#
# E) They eliminate the need for any documentation.
#
#
#
#
#
#
#
# **4.** Which TWO describe why documenting exact software versions matters?
#
#
#
# A) It makes a claimed result checkable months or years later.
#
#
#
# B) "Python 3.10.2" is more useful than just "Python" for reproducibility.
#
#
#
# C) It's only relevant for very large projects.
#
#
#
# D) It replaces the need for a environment file.
#
#
#
# E) It has no effect on reproducibility.
#
#
#
#
#
#
#
# **5.** Which TWO describe what a checksum verifies?
#
#
#
# A) A short fingerprint computed from a file's contents.
#
#
#
# B) Whether a file changed or got corrupted during download.
#
#
#
# C) The exact runtime of a program.
#
#
#
# D) How many collaborators have access to a file.
#
#
#
# E) The programming language a file was written in.
#
#
#
#
#
#
#
# **6.** Splitting a task across 4 cores drops runtime from 100s to 25s. Which TWO are true?
#
#
#
# A) The speedup factor is 4.
#
#
#
# B) This is linear (ideal) speedup for 4 cores.
#
#
#
# C) The speedup factor is 25.
#
#
#
# D) Adding unlimited cores would keep reducing time proportionally forever.
#
#
#
# E) This could only be achieved with a GPU.
#
#
#
#
#
#
#
# **7.** Which TWO describe a parallel bottleneck?
#
#
#
# A) Coordination overhead can outweigh the benefit of adding more processors.
#
#
#
# B) Runtime doesn't keep decreasing forever as you add more cores.
#
#
#
# C) It only happens with exactly 2 processors.
#
#
#
# D) It means parallel computing never provides any speedup.
#
#
#
# E) It is unrelated to how results get combined at the end.
#
#
#
#
#
#
#
# **8.** Which TWO happen with proper per-participant error isolation in a 28-subject batch?
#
#
#
# A) The problem is logged for the one bad subject.
#
#
#
# B) The other 27 subjects continue processing normally.
#
#
#
# C) The entire batch stops immediately.
#
#
#
# D) The bad subject's data is automatically repaired.
#
#
#
# E) The error is silently ignored with no record.
#
#
#
#
#
#
#
# **9.** Which TWO correctly distinguish CPU from GPU?
#
#
#
# A) A GPU handles many simple tasks in parallel across thousands of smaller cores.
#
#
#
# B) A CPU handles complex, varied tasks sequentially across a few powerful cores.
#
#
#
# C) A GPU is primarily used for permanent data storage.
#
#
#
# D) A CPU is always faster than a GPU for every task.
#
#
#
# E) A GPU cannot be used for scientific computing.
#
#
#
#
#
#
#
# **10.** Which TWO correctly describe vibe coding?
#
#
#
# A) Specifying intent to an AI tool in plain language, then evaluating its output.
#
#
#
# B) The core skill is judging correctness, not typing syntax.
#
#
#
# C) It means accepting whatever the AI generates without review.
#
#
#
# D) It eliminates the need to understand the underlying concepts.
#
#
#
# E) It only applies to writing visualization code.
#
#
#
#
#
#
#
# **11.** Which TWO correctly distinguish ACCESS and NAIRR from a single resource like FABRIC?
#
#
#
#
#
#
#
# A. ACCESS coordinates allocations across multiple national supercomputing centers at once.
#
#
#
# B. NAIRR is a national resource created specifically for AI workloads' GPU-heavy compute needs.
#
#
#
# C. ACCESS and FABRIC are the exact same system under two different names.
#
#
#
# D. NAIRR replaced FABRIC entirely, which no longer exists.
#
#
#
# E. ACCESS operates at a smaller total scale than any single university's server.
#
#
#
#
#
#
#
# **12.** Which TWO correctly distinguish classical ML from generative AI?
#
#
#
#
#
#
#
# A. Classical ML (like your Colab 2 CNN) is trained on labeled data for one specific prediction task.
#
#
#
# B. Generative AI is trained to produce open-ended output — text, code, or other content — from a prompt.
#
#
#
# C. Classical ML and generative AI are simply two names for the exact same technology.
#
#
#
# D. A CNN trained to classify EEG conditions is an example of generative AI.
#
#
#
# E. Generative AI cannot be used to assist with writing code.

# %% [markdown]
# ***
#
#
#
#
#
#
#
# ## ✍️ Now It's Your Turn: Write 10 Target Questions of Your Own
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# You've worked through 10 concept resources, hunted down external practice questions for each, and answered the 10 official Target Questions above. Now flip the process: write **10 of your own** target-style questions covering this Colab's material.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Your questions can be:
#
#
#
#
#
#
#
# - Harder or more specific versions of the concepts above,
#
#
#
#
#
#
#
# - Questions about something this Colab covered that wasn't in the official 10,
#
#
#
#
#
#
#
# - Questions inspired by whatever you found during your Find-and-Practice research.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Use the same two-answer-select format (5 options, exactly 2 correct) or a short conceptual question — whichever fits the idea better. Include the correct answer(s) and a one-sentence explanation for each.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **Why this matters:** writing a good test question requires understanding the material more deeply than just answering one — you have to know not just what's true, but what's *plausibly wrong* (the distractors). This is also genuinely useful beyond your own studying: your best questions may get folded into a future semester's quiz bank, the same way the Advanced Explorations Library's Field-Scan Challenge (Option E) uses student proposals to keep that material current.

# %%
# ✍️ Write your 10 original questions, answers, and explanations here:

# %% [markdown]
# ***
#
#
#
# ## 📖 Reference Guide: Concepts Used in Colab 2
#
#
#
#
#
#
#
# **From the master 50:** [Concept 6](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#q6) (Dedicated Software Environments), [Concept 7](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#q7) (Sharing Environments via Environment Files), [Concept 26](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#q26) (Speedup Factor), [Concept 27](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#q27) (Parallel Bottleneck), [Concept 39](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#q39) (Per-Participant Error Isolation).
#
#
#
#
#
#
#
# **From Track B:** [CPU vs. GPU](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#trackB16) (corrected — this isn't in the master 50; it's a new Track B concept).
#
#
#
#
#
#
#
# **From the new AI/Agentic/Physical AI track:** Vibe Coding / AI-Assisted Coding.
#
#
#
#
#
#
#
# **New platform explored via self-directed vibe coding:** CloudLab and Neuroscience Gateway (NSG). *(Globus gets its own self-directed exploration activity in Colab 3.)*
#
#
#
#
#
#
#
# ***
#
#
#
# ## ✅ Self-Check: What Did You Learn?
#
#
#
#
#
#
#
# | Concept Area | Concept | Where You Demonstrated It |
#
#
#
# |---|---|---|
#
#
#
# | Computing | Concept 6 — Dedicated software environments | [ Enter Module ID ] |
#
#
#
# | Computing | Concept 26 — Speedup factor | [ Enter Module ID ] |
#
#
#
# | Computing | Concept 28 — CPU vs. GPU | [ Enter Module ID ] |
#
#
#
# | Computing | Concept 39 — Error-handling / messy-data debugging | [ Enter Module ID ] |
#
#
#
# | AI/Vibe Coding | FABRIC environment setup via vibe coding | [ Enter Activity ID ] |
#
#
#
# | AI/Vibe Coding | Self-directed platform exploration (CloudLab/NSG) | [ Enter Activity ID ] |
#
#
#
#
#
#
#
# **From the Cumulative Microcredential Ladders:** [ACCESS/NAIRR](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#ladder3), [Classical ML vs. Generative AI](https://019fd585-bab7-9f63-bb09-38e93ede654b.share.connect.posit.cloud/certification.html#ladder4).
